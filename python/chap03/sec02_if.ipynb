# %%
ssn: str = "123456-4325673"
sex: int = int(ssn[7])

if sex == 1 or sex == 3:
    print("남자입니다.")
elif sex == 2:
    print("1900년대생 여자입니다.")
elif sex == 4:
    print("2000년대생 여자입니다.")
else:
    print("잘못된 주민등록번호입니다.")
# Out:
# 2000년대생 여자입니다.
