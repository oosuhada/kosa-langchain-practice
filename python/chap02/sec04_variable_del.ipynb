# %%
data = 10
print("data: " + str(data))
print("data:", data)

# del 키워드를 사용하여 변수 이름을 삭제할 수 있다. 그러나 자주 사용하지는 않는다
# 하지만 이는 변수의 참조를 제거하는 것이지, 실제로 메모리에서 데이터를 삭제하는 것은 아니다.
del(data)
# Out:
# data: 10
# data: 10
