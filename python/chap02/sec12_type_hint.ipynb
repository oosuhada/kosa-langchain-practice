# %%
# 변수에 타입 힌트를 작성할 때는 변수명 뒤에 콜론(:)과 타입을 명시한다.
name: str = "장우수"
age: int = 34 #int 값으로 타입 힌트가 작성되었지만 문자열이 입력되어도 실행에는 오류가 발생하지는 않는다. 하지만 타입 힌트는 개발자에게 변수의 예상 타입을 알려주는 역할을 하므로, age 변수에는 정수값이 할당되는 것이 바람직하다.
#age: int = "34" #setting.json 파일에서의 "python.analysis.typeCheckingMode": "standard" 설정을 통해 type error가 발생한다.
height: float = 183.5
is_student: bool = True

# 파이썬의 Any 타입은 Java에서 Object 타입과 유사한 역할을 한다.
from re import A
from typing import Any
data: Any = "Hello, World!"  # 문자열이 할당된 Any 타입 변수
print(data)  # Hello, World!

value: Any = "장우수"
value: Any = 34
value: Any = 183.5
value: Any = True

# %%
name1: str = "장우수" #핋수값
name2: str | None = "장우수" #유니언 타입 or 옵셔널. name2 변수에는 문자열이 할당될 수도 있고, None이 할당될 수도 있다.
