# %%
# 변수 선언
name = "Gabriel"
job = "Programmer"
age = 34
length = 180.5

# 파이썬은 큰 수를 다루는 데 제한이 없다. 매우 큰 수를 사용할 수 있어서 유용하다.
# 메모리 사용량이 증가할 수 있지만, 파이썬은 자동으로 메모리를 관리하기 때문에 걱정할 필요는 없다.
# 메모리 허용량이 초과되지 않는 한, 무제한으로 큰 수를 사용할 수 있다.
big_number = 1234567890123456789012345678901234567890

# %%
# 조금 불편해도 가독성은 좋다
a = 8
b = 8
c = 8

# 한 줄로 작성하면 편하지만 가독성이 떨어진다
a = b = c = 8

a, b, c = 8, 8, 8

# 혹은 이렇게도 활용이 가능하다. 사용은 가능하지만 가독성은 떨어진다.
a, b, c = 8, "파이썬", True

# %%
# 파이썬의 모든 변수는 번지를 가지는 참조 변수
# 변수는 값을 직접 담기보다 객체를 가리키는 이름(name)처럼 동작한다.
# 아직 번지가 없다는 뜻에서 None을 할당할 수 있다.(null과 유사)
변수 = None

# %%
# 변수 이름은 모두 소문자를 사용하는 것이 일반적 관례이다.
# 여러 단어로 구성된 변수명은 언더스코어(_)로 구분한다. (snake_case)
# 변수명은 의미 있게 작성하는 것이 좋다. 가독성이 좋아지고 유지보수가 쉬워진다.
first_name = "Gabriel"
last_name = "Smith"
math_score = 95
is_passed = True

# %%
# camelCase는 자바스크립트에서 주로 사용되는 변수명 작성 방식이다. 파이썬에서는 snake_case를 권장한다.
# 변수/함수는 snake_case, 클래스 이름은 PascalCase를 권장한다.
# 예외적으로 파이썬에서도 camelCase를 사용하는 경우가 있는데, 이는 주로 클래스 이름에서 사용된다. (camelCase가 아닌 PascalCase라고 불린다.)
class Memeber:
    pass


class MemberService:
    pass
